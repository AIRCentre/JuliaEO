# %% [markdown]
# # Tutorial on DINCAE
#
# This script/notebook reconstructs missing data in satellite data using a neural
# network architecture called convolutional auto-encoder described in the
# following articles:
#
# * Barth, A., Alvera-Azcárate, A., Licer, M., and Beckers, J.-M.: DINCAE 1.0: a convolutional neural network with error estimates to reconstruct sea surface temperature satellite observations, Geosci. Model Dev., 13, 1609–1622, https://doi.org/10.5194/gmd-13-1609-2020, 2020.
# * Barth, A., Alvera-Azcárate, A., Troupin, C., & Beckers, J.-M. (2022). DINCAE 2.0: multivariate convolutional neural network with error estimates to reconstruct sea surface temperature satellite and altimetry observations. Geoscientific Model Development, 15(5), 2183–2196. https://doi.org/10.5194/gmd-15-2183-2022
#
# The example here uses MODIS sea surface temperature from the Physical
# Oceanography Distributed Active Archive Center (PO.DAAC) JPL, NASA.
# More information is available at https://dx.doi.org/10.5067/MODST-1D4D9
#
# This notebook/script is indented to be run on a GPU with CUDA support (NVIDIA GPU)
# with a least 8 GB of RAM.

# %% [markdown]
# Dependencies are installed with:
#
# ```julia
# using Pkg
# Pkg.add(["CUDA","Knet","NCDatasets","PyPlot"])
# Pkg.add(url="https://github.com/gher-uliege/DINCAE_utils.jl", rev="main")
# ```
#
# See also https://github.com/gher-ulg/DINCAE.jl#installation
#
# Load the necessary modules

# %%
using CUDA
using DINCAE
using DINCAE_utils
using Dates
using Knet
using NCDatasets
using PyPlot
using Printf
using Downloads: download

# %% [markdown]
# ## Data download/processing
#
# First we define the domain and time interval.
#
# The example is tested here for a short time frame but for realistic
# applications one should use a much longer time-range (like 10, 20 years or more)
#
# Place the files modis_subset.nc and data-avg.nc (if you have them already)
# in your current working directory.
# They are downloaded is not present, but they are very large (400 MB).

# %%
# longitude range (east, west)
lon_range = [-33, -24]
# latitude range (south, north)
lat_range = [33.0, 40.0]
# Out:
# 2-element Vector{Float64}:
#  33.0
#  40.0

# %%
# time range (start, end)
time_range = [DateTime(2017,1,1), DateTime(2019,12,31)]
# Out:
# 2-element Vector{DateTime}:
#  2017-01-01T00:00:00
#  2019-12-31T00:00:00

# %%
# local directory
localdir = "."
# create directory
mkpath(localdir)
# filename of the subset
fname_subset = joinpath(localdir,"modis_subset.nc")
# filename of the clean data
fname = joinpath(localdir,"modis_cleanup.nc")
# filename of the data with added clouds for cross-validation
fname_cv = joinpath(localdir,"modis_cleanup_add_clouds.nc")
varname = "sst"
# Out:
# "sst"

# %% [markdown]
# Results of DINCAE will be placed in a sub-directory under `localdir`

# %%
outdir = "."
mkpath(outdir)
# Out:
# ""

# %% [markdown]
# Download the MODIS subset:

# %%
if !isfile(fname_subset)
    download("https://dox.ulg.ac.be/index.php/s/a1Lk2sG4onZR5Gg/download",fname_subset)
end

# %% [markdown]
# The MODIS subset was generated by the following code:
#
# ```julia
# for dt in time_range[1]:Day(1):time_range[end]
#     yyyy = Dates.format(dt,"yyyy")
#     mm = Dates.format(dt,"mm")
#     dd = Dates.format(dt,"dd")
#     doy = @sprintf("%03d",Dates.dayofyear(dt))
#     url = "https://podaac-opendap.jpl.nasa.gov:443/opendap/allData/modis/L3/terra/11um/v2019.0/4km/daily/$yyyy/$doy/TERRA_MODIS.$(yyyy)$(mm)$(dd).L3m.DAY.NSST.sst.4km.nc"
#     filename = joinpath(localdir,"TERRA_MODIS.$(yyyy)$(mm)$(dd).L3m.DAY.NSST.sst.4km.nc")
#     if isfile(filename)
#         continue
#     end
#     try
#         ds = NCDataset(url)
#         ds_subset = NCDatasets.@select(ds,$(lon_range[1]) <= lon <= $(lon_range[2]) && $(lat_range[1]) <= lat <= $(lat_range[2]))
#         write(filename,ds_subset)
#         push!(filenames,filename)
#         close(ds)
#         println("$dt downloaded")
#     catch e
#         showerror(stdout, e)
#         @warn("no data for $dt")
#     end
# end
#
# filenames = String[]
# time = DateTime[]
#
# for dt in time_range[1]:Day(1):time_range[end]
#     yyyy = Dates.format(dt,"yyyy")
#     mm = Dates.format(dt,"mm")
#     dd = Dates.format(dt,"dd")
#     filename = joinpath(localdir,"TERRA_MODIS.$(yyyy)$(mm)$(dd).L3m.DAY.NSST.sst.4km.nc")
#     if isfile(filename)
#         push!(filenames,filename)
#         push!(time,dt)
#     end
# end
#
# ds = NCDataset(filenames,aggdim="time",isnewdim=true,
#                constvars = ["lon","lat"]);
# ds2 = NCDataset(fname_subset,"c")
# write(ds2,ds)
# defVar(ds2,"time",time,("time",))
# close(ds2)
# close(ds)
# ```

# %%
ds = NCDataset(fname_subset,"r")
sst = ds["sst"][:,:,:];
qual = ds["qual_sst"][:,:,:];

# %%
@show extrema(skipmissing(qual))
@show extrema(skipmissing(sst))
# Out:
# extrema(skipmissing(qual)) = (0, 2)
# extrema(skipmissing(sst)) = (9.995f0, 28.21f0)
# (9.995f0, 28.21f0)

# %% [markdown]
# We ignore all data points with missing quality flags,
# quality indicator exceeding 3 and temperature
# larger than 40°C (not necessary for this particular dataset)

# %%
sst_t = copy(sst)
sst_t[(qual .> 3) .& .!ismissing.(qual)] .= missing
sst_t[(sst_t .> 40) .& .!ismissing.(sst_t)] .= missing
# Out:
# 0-element view(reshape(::Array{Union{Missing, Float32}, 3}, 39662784), Int64[]) with eltype Union{Missing, Float32}

# %%
@info "number of missing observations: $(count(ismissing,sst_t))"
@info "number of valid observations: $(count(.!ismissing,sst_t))"
# Out:
# [ Info: number of missing observations: 25591782
# [ Info: number of valid observations: 14071002

# %% [markdown]
# Clean-up the data to them write to disk

# %%
isfile("modis_cleanup.nc") && rm("modis_cleanup.nc")
varname = "sst"
fname = joinpath(localdir,"modis_cleanup.nc")
ds2 = NCDataset(fname,"c")
write(ds2,ds,exclude = ["sst","qual"])
defVar(ds2,varname,sst_t,("lon","lat","time"))
close(ds2)
# Out:
# closed NetCDF NCDataset

# %% [markdown]
# Add a land-sea mask to the file grid points with less than 5% of
# valid data are considerd as land

# %%
DINCAE_utils.add_mask(fname,varname; minseafrac = 0.05)
# Out:
# NetCDF variable (file closed)

# %% [markdown]
# Choose cross-validation points by adding clouds to the cleanest
# images (copied from the cloudiest images). This function will generate
# a file `fname_cv`.

# %%
DINCAE_utils.addcvpoint(fname,varname; mincvfrac = 0.10);
# Out:
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (607, DateTime("2018-08-30T00:00:00"), 16301, 16301, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (930, DateTime("2019-07-20T00:00:00"), 22697, 38998, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (921, DateTime("2019-07-11T00:00:00"), 19630, 58628, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (593, DateTime("2018-08-16T00:00:00"), 27017, 85645, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (46, DateTime("2017-02-15T00:00:00"), 17628, 103273, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (588, DateTime("2018-08-11T00:00:00"), 24904, 128177, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (618, DateTime("2018-09-10T00:00:00"), 23453, 151630, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (275, DateTime("2017-10-02T00:00:00"), 23145, 174775, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (595, DateTime("2018-08-18T00:00:00"), 21298, 196073, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (926, DateTime("2019-07-16T00:00:00"), 6695, 202768, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (592, DateTime("2018-08-15T00:00:00"), 21759, 224527, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (175, DateTime("2017-06-24T00:00:00"), 27571, 252098, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (632, DateTime("2018-09-24T00:00:00"), 19980, 272078, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (923, DateTime("2019-07-13T00:00:00"), 27086, 299164, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (972, DateTime("2019-08-31T00:00:00"), 19742, 318906, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (273, DateTime("2017-09-30T00:00:00"), 15932, 334838, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (942, DateTime("2019-08-01T00:00:00"), 10681, 345519, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (268, DateTime("2017-09-25T00:00:00"), 7619, 353138, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (225, DateTime("2017-08-13T00:00:00"), 20077, 373215, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (973, DateTime("2019-09-01T00:00:00"), 30047, 403262, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (606, DateTime("2018-08-29T00:00:00"), 10272, 413534, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (627, DateTime("2018-09-19T00:00:00"), 21917, 435451, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (48, DateTime("2017-02-17T00:00:00"), 13457, 448908, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (211, DateTime("2017-07-30T00:00:00"), 23921, 472829, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (928, DateTime("2019-07-18T00:00:00"), 26169, 498998, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (609, DateTime("2018-09-01T00:00:00"), 16066, 515064, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (228, DateTime("2017-08-16T00:00:00"), 11340, 526404, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (1008, DateTime("2019-10-06T00:00:00"), 27186, 553590, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (617, DateTime("2018-09-09T00:00:00"), 19802, 573392, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (214, DateTime("2017-08-02T00:00:00"), 28367, 601759, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (629, DateTime("2018-09-21T00:00:00"), 19856, 621615, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (630, DateTime("2018-09-22T00:00:00"), 27819, 649434, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (619, DateTime("2018-09-11T00:00:00"), 13819, 663253, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (929, DateTime("2019-07-19T00:00:00"), 12621, 675874, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (997, DateTime("2019-09-25T00:00:00"), 15253, 691127, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (230, DateTime("2017-08-18T00:00:00"), 24736, 715863, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (206, DateTime("2017-07-25T00:00:00"), 5535, 721398, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (207, DateTime("2017-07-26T00:00:00"), 25849, 747247, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (922, DateTime("2019-07-12T00:00:00"), 23162, 770409, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (956, DateTime("2019-08-15T00:00:00"), 16836, 787245, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (943, DateTime("2019-08-02T00:00:00"), 22553, 809798, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (919, DateTime("2019-07-09T00:00:00"), 23272, 833070, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (529, DateTime("2018-06-13T00:00:00"), 9275, 842345, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (274, DateTime("2017-10-01T00:00:00"), 24790, 867135, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (1001, DateTime("2019-09-29T00:00:00"), 17817, 884952, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (620, DateTime("2018-09-12T00:00:00"), 17358, 902310, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (245, DateTime("2017-09-02T00:00:00"), 22658, 924968, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (205, DateTime("2017-07-24T00:00:00"), 14509, 939477, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (927, DateTime("2019-07-17T00:00:00"), 14742, 954219, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (944, DateTime("2019-08-03T00:00:00"), 8447, 962666, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (631, DateTime("2018-09-23T00:00:00"), 12854, 975520, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (957, DateTime("2019-08-16T00:00:00"), 22934, 998454, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (705, DateTime("2018-12-06T00:00:00"), 16964, 1015418, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (597, DateTime("2018-08-20T00:00:00"), 9643, 1025061, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (589, DateTime("2018-08-12T00:00:00"), 7753, 1032814, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (517, DateTime("2018-06-01T00:00:00"), 24548, 1057362, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (137, DateTime("2017-05-17T00:00:00"), 13538, 1070900, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (664, DateTime("2018-10-26T00:00:00"), 23450, 1094350, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (608, DateTime("2018-08-31T00:00:00"), 9088, 1103438, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (131, DateTime("2017-05-11T00:00:00"), 17840, 1121278, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (707, DateTime("2018-12-08T00:00:00"), 14250, 1135528, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (285, DateTime("2017-10-12T00:00:00"), 18691, 1154219, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (958, DateTime("2019-08-17T00:00:00"), 8908, 1163127, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (946, DateTime("2019-08-05T00:00:00"), 11516, 1174643, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (227, DateTime("2017-08-15T00:00:00"), 18687, 1193330, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (611, DateTime("2018-09-03T00:00:00"), 17900, 1211230, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (1044, DateTime("2019-11-11T00:00:00"), 22378, 1233608, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (596, DateTime("2018-08-19T00:00:00"), 16296, 1249904, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (71, DateTime("2017-03-12T00:00:00"), 8966, 1258870, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (74, DateTime("2017-03-15T00:00:00"), 11965, 1270835, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (746, DateTime("2019-01-16T00:00:00"), 22378, 1293213, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (582, DateTime("2018-08-05T00:00:00"), 11601, 1304814, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (912, DateTime("2019-07-02T00:00:00"), 12618, 1317432, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (49, DateTime("2017-02-18T00:00:00"), 8784, 1326216, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (945, DateTime("2019-08-04T00:00:00"), 11274, 1337490, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (876, DateTime("2019-05-26T00:00:00"), 20045, 1357535, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (538, DateTime("2018-06-22T00:00:00"), 17138, 1374673, 1.4070414000000001e6)
# (n_dest, time[n_dest], nmissing_after - nmissing_before, ncv, mincvfrac * nvalid) = (999, DateTime("2019-09-27T00:00:00"), 25451, 1400124, 1.4070414000000001e6)
# ┌ Info: number cross-validation points
# └   ncv = 1416523
# ┌ Info: percentage of cross-validation points
# └   (100ncv) / nvalid = 10.067386787624017

# %% [markdown]
# # Reconstruct missing data
#
#
# F is the floating point number type for neural network, here we use
# single precision

# %%
const F = Float32
# Out:
# Float32

# %% [markdown]
# Test if CUDA is functional to use the GPU, otherwise the CPU is used.

# %%
if CUDA.functional()
    Atype = KnetArray{F}
else
    @warn "No supported GPU found. We will use the CPU which is very slow. Please check https://developer.nvidia.com/cuda-gpus"
    Atype = Array{F}
end
# Out:
# ┌ Warning: No supported GPU found. We will use the CPU which is very slow. Please check https://developer.nvidia.com/cuda-gpus
# └ @ Main In[15]:4
# Array{Float32}

# %%
Knet.atype() = Atype

# %% [markdown]
# Setting the paramenters of neural network
# see document of DINCAE.reconstruct for more information

# %%
epochs = 1000
batch_size = 32
enc_nfilter_internal = round.(Int,32 * 2 .^ (0:4))
clip_grad = 5.0
regularization_L2_beta = 0
ntime_win = 3
upsampling_method = :nearest
loss_weights_refine = (0.3,0.7)
save_epochs = 200:10:epochs
# Out:
# 200:10:1000

# %%
data = [
   (filename = fname_cv,
    varname = varname,
    obs_err_std = 1,
    jitter_std = 0.05,
    isoutput = true,
   )
]
data_test = data;
fnames_rec = [joinpath(outdir,"data-avg.nc")]
data_all = [data,data_test]
# Out:
# 2-element Vector{Vector{NamedTuple{(:filename, :varname, :obs_err_std, :jitter_std, :isoutput), Tuple{String, String, Int64, Float64, Bool}}}}:
#  [(filename = "./modis_cleanup_add_clouds.nc", varname = "sst", obs_err_std = 1, jitter_std = 0.05, isoutput = 1)]
#  [(filename = "./modis_cleanup_add_clouds.nc", varname = "sst", obs_err_std = 1, jitter_std = 0.05, isoutput = 1)]

# %% [markdown]
# Use these parameters for a quick test:

# %% [markdown]
# epochs = 10
# save_epochs = epochs:epochs

# %% [markdown]
# Start the training and reconstruction of the neural network
# This takes a long time. You can cancel this step and get the
# sample result.
#
# ```julia
# loss = DINCAE.reconstruct(
#     Atype,data_all,fnames_rec;
#     epochs = epochs,
#     batch_size = batch_size,
#     enc_nfilter_internal = enc_nfilter_internal,
#     clip_grad = clip_grad,
#     save_epochs = save_epochs,
#     upsampling_method = upsampling_method,
#     loss_weights_refine = loss_weights_refine,
#     ntime_win = ntime_win,
# )
# ```

# %% [markdown]
# Download the result and load the loss

# %%
if !isfile(fnames_rec[1])
    download("https://dox.ulg.ac.be/index.php/s/91OnKoK0CUE3a8V/download",fnames_rec[1])
end
loss =
    NCDataset(fnames_rec[1]) do ds
        ds["losses"][:]
    end
# Out:
# 1000-element Vector{Float64}:
#   2.6509844498974933
#   0.6473746311664579
#   0.4215355967623848
#   0.23523193581561955
#   0.21966957172462045
#   0.1155703649523535
#   0.04859859980725948
#   0.016391583709378856
#  -0.012983327716522454
#  -0.06504221366585364
#  -0.06483554802751834
#  -0.14255169023626615
#  -0.10839240813561317
#   ⋮
#  -1.4069635360581532
#  -1.4293950176239014
#  -1.4458727683339798
#  -1.40832601921899
#  -1.4276547837257383
#  -1.4886608569962638
#  -1.4945108910969325
#  -1.505952879531043
#  -1.4996476789883204
#  -1.486514375209808
#  -1.4359892674854826
#  -1.4075962257385257

# %% [markdown]
# Plot the loss function

# %%
plot(loss)
ylim(extrema(loss[2:end]))
xlabel("epochs")
ylabel("loss");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # Post process results
#
# Compute the RMS with the independent validation data

# %%
case = (
    fname_orig = fname,
    fname_cv = fname_cv,
    varname = varname,
)
fnameavg = joinpath(outdir,"data-avg.nc")
cvrms = DINCAE_utils.cvrms(case,fnameavg)
@info "Cross-validation RMS error is: $cvrms"
# Out:
# [ Info: Cross-validation RMS error is: 0.359548

# %% [markdown]
# Next we plot all time instances. The figures with be placed in the
# directory `figdir`

# %%
figdir = joinpath(outdir,"Fig")
DINCAE_utils.plotres(case,fnameavg, clim = nothing, figdir = figdir,
                     clim_quantile = (0.01,0.99),
                     which_plot = :cv)
@info "Figures are in $(figdir)"
# Out:
# plot 2017-02-15T00:00:00
# plot 2017-02-17T00:00:00
# plot 2017-02-18T00:00:00
# plot 2017-03-12T00:00:00
# plot 2017-03-15T00:00:00
# plot 2017-05-11T00:00:00
# plot 2017-05-17T00:00:00
# plot 2017-06-24T00:00:00
# plot 2017-07-24T00:00:00
# plot 2017-07-25T00:00:00
# plot 2017-07-26T00:00:00
# plot 2017-07-30T00:00:00
# plot 2017-08-02T00:00:00
# plot 2017-08-13T00:00:00
# plot 2017-08-15T00:00:00
# plot 2017-08-16T00:00:00
# plot 2017-08-18T00:00:00
# plot 2017-09-02T00:00:00
# plot 2017-09-25T00:00:00
# plot 2017-09-30T00:00:00
# plot 2017-10-01T00:00:00
# plot 2017-10-02T00:00:00
# plot 2017-10-12T00:00:00
# plot 2018-06-01T00:00:00
# plot 2018-06-13T00:00:00
# plot 2018-06-22T00:00:00
# plot 2018-08-05T00:00:00
# plot 2018-08-11T00:00:00
# plot 2018-08-12T00:00:00
# plot 2018-08-15T00:00:00
# plot 2018-08-16T00:00:00
# plot 2018-08-18T00:00:00
# plot 2018-08-19T00:00:00
# plot 2018-08-20T00:00:00
# plot 2018-08-25T00:00:00
# plot 2018-08-29T00:00:00
# plot 2018-08-30T00:00:00
# plot 2018-08-31T00:00:00
# plot 2018-09-01T00:00:00
# plot 2018-09-03T00:00:00
# plot 2018-09-09T00:00:00
# plot 2018-09-10T00:00:00
# plot 2018-09-11T00:00:00
# plot 2018-09-12T00:00:00
# plot 2018-09-19T00:00:00
# plot 2018-09-21T00:00:00
# plot 2018-09-22T00:00:00
# plot 2018-09-23T00:00:00
# plot 2018-09-24T00:00:00
# plot 2018-10-26T00:00:00
# plot 2018-12-06T00:00:00
# plot 2018-12-08T00:00:00
# plot 2019-01-16T00:00:00
# plot 2019-05-26T00:00:00
# plot 2019-07-02T00:00:00
# plot 2019-07-09T00:00:00
# plot 2019-07-11T00:00:00
# plot 2019-07-12T00:00:00
# plot 2019-07-13T00:00:00
# plot 2019-07-16T00:00:00
# plot 2019-07-17T00:00:00
# plot 2019-07-18T00:00:00
# plot 2019-07-19T00:00:00
# plot 2019-07-20T00:00:00
# plot 2019-08-01T00:00:00
# plot 2019-08-02T00:00:00
# plot 2019-08-03T00:00:00
# plot 2019-08-04T00:00:00
# plot 2019-08-05T00:00:00
# plot 2019-08-15T00:00:00
# plot 2019-08-16T00:00:00
# plot 2019-08-17T00:00:00
# plot 2019-08-31T00:00:00
# plot 2019-09-01T00:00:00
# plot 2019-09-25T00:00:00
# plot 2019-09-27T00:00:00
# plot 2019-09-29T00:00:00
# plot 2019-10-06T00:00:00
# plot 2019-11-11T00:00:00
# [ Info: Figures are in ./Fig
# Figure(PyObject <Figure size 1000x700 with 8 Axes>)
